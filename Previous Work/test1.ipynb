# %%
inpfile=open('English_Updated.txt','r',encoding="utf8")
inpfile1=open('Dutch_Updated.txt','r',encoding="utf8")
l=inpfile.readlines()
l1=inpfile1.readlines()

ofile=open("English_Train.txt","w",encoding="utf-8")
ofile2=open("Dutch_Train.txt","w",encoding="utf-8")
for i,sentence in enumerate(l):
    if len(sentence.split())<5 and len(l1[i].split())<5 :
        ofile.write(sentence)
        ofile2.write(l1[i])
    '''try:
        w[len(sentence.split())]+=1
        #print(sentence.split())
    except:
        pass
'''
inpfile.close()
inpfile1.close()
ofile.close()
ofile2.close()
print("done")
# Out:
# done

# %%
ofile2.close()

# %%
a=[1,2,3,4]
print(a[:-1])
# Out:
# [1, 2, 3]

# %%
# Out:
# 2019-11-04 17:53:34,753 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-11-04 17:53:34,754 INFO sqlalchemy.engine.base.Engine ()
# 2019-11-04 17:53:34,756 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-11-04 17:53:34,758 INFO sqlalchemy.engine.base.Engine ()
# 2019-11-04 17:53:34,759 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("tProb")
# 2019-11-04 17:53:34,760 INFO sqlalchemy.engine.base.Engine ()
# 2019-11-04 17:53:34,767 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("tProb")
# 2019-11-04 17:53:34,771 INFO sqlalchemy.engine.base.Engine ()
# 2019-11-04 17:53:34,774 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "tProb" (
# 	english VARCHAR NOT NULL,
# 	dutch VARCHAR NOT NULL,
# 	prob FLOAT,
# 	CONSTRAINT "tProb" PRIMARY KEY (english, dutch)
# )
#
#
# 2019-11-04 17:53:34,776 INFO sqlalchemy.engine.base.Engine ()
# ...
